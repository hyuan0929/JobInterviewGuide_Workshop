# %% [markdown]
# ## Group 1 – LLM Interview Session
#
# This notebook documents the AI-assisted interview preparation process conducted by Group 1 as part of the Job Interview Guide Workshop.

# %% [markdown]
# ### Prompt Used
#
# The team used the interview simulation prompt provided in the workshop to generate:
#
# - Knowledge coverage summary
# - Interview topic summary
# - Gap analysis
# - A 15-question simulated quiz

# %% [markdown]
# ### Summary of Results
#
# Group 1 completed a simulated interview session.
#
# Key outcomes included:
#
# - Identification of gaps in Train/Test splitting strategies
# - Need for deeper understanding of Cross-Entropy
# - Better interpretation of KNN hyperparameters
#
# These insights informed the targeted practice exercises completed in the main notebook.
